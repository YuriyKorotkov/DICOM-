# %% [markdown]
# <a href="https://colab.research.google.com/github/NeuronsUII/Pathologies_ArtDental_n/blob/main/Kotov%20Alexander/Sagittal_train_yolov8_object_detection_on_custom_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics==8.0.196

from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.5/78.2 GB disk)

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# ### 🐍 Python SDK
#
# The simplest way of simply using YOLOv8 directly in a Python environment.

# %%
# !nvidia-smi
import os
# Out:
# Fri Mar  1 15:18:38 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8               9W /  70W |      3MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %%
HOME = os.getcwd()
print(HOME)
# !mkdir {HOME}/datasets
# %cd {HOME}/datasets

#!pip install roboflow --quiet

#from roboflow import Roboflow
#rf = Roboflow(api_key="YOUR_API_KEY")
#project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
#dataset = project.version(1).download("yolov8")

# sagittal
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="O364CBvA6Pd5qZBEH6EJ")
project = rf.workspace("joint-pathologies").project("sagittal-joints")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# /content
# mkdir: cannot create directory ‘/content/datasets’: File exists
# /content/datasets
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# ## Custom Training

# %%
# %cd {HOME}

# !yolo task=detect mode=train model=yolov8n.pt data={dataset.location}/data.yaml epochs=200 imgsz=416 plots=True
# Out:
# /content
# ...
# 100% 6.23M/6.23M [00:00<00:00, 68.4MB/s]
# New https://pypi.org/project/ultralytics/8.1.20 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# args.yaml					    PR_curve.png	   val_batch0_pred.jpg
# confusion_matrix_normalized.png			    R_curve.png		   val_batch1_labels.jpg
# confusion_matrix.png				    results.csv		   val_batch1_pred.jpg
# events.out.tfevents.1709306352.db7ef3086363.1438.0  results.png		   val_batch2_labels.jpg
# F1_curve.png					    train_batch0.jpg	   val_batch2_pred.jpg
# labels_correlogram.jpg				    train_batch1.jpg	   weights
# labels.jpg					    train_batch2.jpg
# P_curve.png					    val_batch0_labels.jpg

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/confusion_matrix.png', width=600)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/results.png', width=416)
# Out:
# /content

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train/val_batch0_pred.jpg', width=416)
# Out:
# /content

# %% [markdown]
# ## Validate Custom Model

# %%
# %cd {HOME}

# !yolo task=detect mode=val model={HOME}/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml
# Out:
# /content
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
# val: Scanning /content/datasets/Sagittal-Joints-1/valid/labels.cache... 76 images, 0 backgrounds, 0 corrupt: 100% 76/76 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 5/5 [00:03<00:00,  1.44it/s]
#                    all         76         76      0.999          1      0.995      0.715
# Speed: 4.2ms preprocess, 15.1ms inference, 0.0ms loss, 9.5ms postprocess per image
# Results saved to runs/detect/val
# 💡 Learn more at https://docs.ultralytics.com/modes/val

# %% [markdown]
# ## Inference with Custom Model

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source={dataset.location}/test/images save=True
# Out:
# /content
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/51 /content/datasets/Sagittal-Joints-1/test/images/l_sag_0477_-33_png.rf.ccb03950ba46839bca5fd1b7100024f7.jpg: 416x416 1 Sagittal-Joints, 10.0ms
# image 2/51 /content/datasets/Sagittal-Joints-1/test/images/l_sag_0624_-253_png.rf.f675501a5b7e0a119870a0f44bc3e13d.jpg: 416x416 1 Sagittal-Joints, 6.8ms
# image 3/51 /content/datasets/Sagittal-Joints-1/test/images/l_sag_0670_-25_png.rf.f23d1c8fcb589e493bf357dea582ab9d.jpg: 416x416 1 Sagittal-Joints, 6.4ms
# image 4/51 /content/datasets/Sagittal-Joints-1/test/images/l_sag_0671_-158_png.rf.a67cebdd1302c73cbb6f48fa55a90e2f.jpg: 416x416 1 Sagittal-Joints, 6.1ms
# ...

# %% [markdown]
# **NOTE:** Let's take a look at few results.

# %%
model = YOLO(f'{HOME}/yolov8n.pt')
#results = model.predict(source='/content/datasets/Joints-1/test/images/l_cor_0385-132_png.rf.269bb867ff7113338c3297ea094e915b.jpg', conf=0.25)
# !yolo task=detect mode=predict model={HOME}/runs/detect/train/weights/best.pt conf=0.25 source='/content/datasets/Sagittal-Joints-1/test/images/l_sag_0477_-33_png.rf.ccb03950ba46839bca5fd1b7100024f7.jpg' save=True
# Out:
# Ultralytics YOLOv8.0.196 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 3005843 parameters, 0 gradients, 8.1 GFLOPs
#
# WARNING ⚠️ NMS time limit 0.550s exceeded
# image 1/1 /content/datasets/Sagittal-Joints-1/test/images/l_sag_0477_-33_png.rf.ccb03950ba46839bca5fd1b7100024f7.jpg: 416x416 1 Sagittal-Joints, 11.1ms
# Speed: 1.5ms preprocess, 11.1ms inference, 683.3ms postprocess per image at shape (1, 3, 416, 416)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %%
# %cd {HOME}
model = YOLO(f'{HOME}/runs/detect/train/weights/best.pt')
results = model.predict(source='/content/datasets/Sagittal-Joints-1/test/images/l_sag_0477_-33_png.rf.ccb03950ba46839bca5fd1b7100024f7.jpg', conf=0.25)
# Out:
# /content
# image 1/1 /content/datasets/Sagittal-Joints-1/test/images/l_sag_0477_-33_png.rf.ccb03950ba46839bca5fd1b7100024f7.jpg: 416x416 1 Sagittal-Joints, 10.4ms
# Speed: 1.7ms preprocess, 10.4ms inference, 534.6ms postprocess per image at shape (1, 3, 416, 416)

# %%
results[0].boxes.xyxy
# Out:
# tensor([[196.2310,  51.7655, 276.6679,  93.8741]], device='cuda:0')

# %%
results[0].boxes.conf
# Out:
# tensor([0.8311], device='cuda:0')

# %%
results[0].boxes.cls
# Out:
# tensor([0.], device='cuda:0')

# %%
#### нужно проверить!!!

# Extract bounding boxes, classes, names, and confidences
boxes = results[0].boxes.xyxy.tolist()
classes = results[0].boxes.cls.tolist()
names = results[0].names
confidences = results[0].boxes.conf.tolist()

# Iterate through the results
for box, cls, conf in zip(boxes, classes, confidences):
    x1, y1, x2, y2 = box
    confidence = conf
    detected_class = cls
    name = names[int(cls)]

# %%
import glob
from IPython.display import Image, display

for image_path in glob.glob(f'{HOME}/runs/detect/predict/*.jpg')[:3]:
      display(Image(filename=image_path, width=600))
      print("\n")

# %%
# !zip -r -q '/content/runs.zip' /content/runs
